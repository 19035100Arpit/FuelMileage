# %%
# importing pandas module
import pandas as pd
import numpy as np
	
# making data frame
df = pd.read_csv("car details v3.csv")
	
df.head(10)
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6          Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                    Maruti 800 DX BSII  2001          45000       5000
# 8                      Toyota Etios VXD  2011         350000      90000
# 9  Ford Figo Diesel Celebration Edition  2013         200000     169000
#
#      fuel seller_type transmission         owner     mileage   engine  \
# 0  Diesel  Individual       Manual   First Owner   23.4 kmpl  1248 CC
# ...

# %%
# Given data
initial_distance = 250  # km
additional_distance = 531525  # km
price_per_liter = 95  # Rs/Lt
total_liters = 10  # liters
efficiency = 13  # Km/Lt

# %%
# Calculate the total distance traveled
total_distance = initial_distance + additional_distance

# %%
# Calculate the total amount of petrol used
total_petrol_used = total_distance / efficiency

# %%
# Calculate the average mileage (fuel efficiency)
average_mileage = total_distance / total_petrol_used

# %%
# Print the average mileage
print(f"Average Mileage (Fuel Efficiency): {average_mileage:.2f} Km/Lt")
# Out:
# Average Mileage (Fuel Efficiency): 13.00 Km/Lt
